# %% [markdown]
# lesson 7 is if statement and indentions, as well as comparison characters
# indentation with the tab like russian dolls

# %%
x = 0
y = 0
if x == 0:
    if y == 0:
        print("Both x and y are zero.")

# %% [markdown]
# Lesson 8
# More conditional structures
# if else
#
# multi way:
# if elif else
#
# try and except

# %%
hour = int(input("Enter hour: "))
rate = float(input("Enter rate: "))

if hour > 40:
    overtime = hour - 40
    pay = (40 * rate) + (overtime * rate * 1.5)
else:
    pay = hour * rate

# %%
try:
    hour = float(input("Enter hour: "))
    rate = float(input("Enter rate: "))
except:
    print("Error, please enter numeric input")
    #quit()
if hour > 40:
    overtime = hour - 40
    pay = (40 * rate) + (overtime * rate * 1.5)
else:
    pay = hour * rate

# %% [markdown]
# Lesson 9
# Python function
#
# def is a key word
#
# function()

# %% [markdown]
# Lesson 10

# %% [markdown]
# Lesson 11
