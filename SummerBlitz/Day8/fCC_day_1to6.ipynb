# %% [markdown]
# First lesson was on introduction you are the intermediary between the computer and the end user

# %% [markdown]
# Second is about hardware architecture; computers are combinations of hardware such as cpus, ram and storage which are all
# installed on a motheroard

# %% [markdown]
# Third lesson Syntax errors
#
# ```python
# x = 6
# print(x)
# ```

# %% [markdown]
# Forth was an intro to functions, keywords and basic use cases

# %% [markdown]
# Chapter 2
# constants: thing that do not change
# Reserved words: special key words that have functions
# variables: they store data like so:
#     ```python
#     x = 3
#     ```

# %% [markdown]
# Expressions
#
# operators: + - * / // % = ** ()
#
# BODMAS or Pa po m a l-t-r
#
# data types: int, float, strings, bool,
# type(var) to check the data type
#
# to convert one to a nother we use
# str(), float(), int()
#
# # and ''' word ''' """ word """ are comments

# %%
#Exercise 1

print('Hello')

# use python3 [filename].py to run the code
#Exercise 2

use = input('What is your name? ')
print('Hello, ' + use + '!')

hour = input('What hour is it? ')
hour = int(hour)

rate = input('What is the rate? ')
rate = float(rate)

pay = hour * rate
print('Your pay is: ' + str(pay))

# %%
def elivator_convert():
    floor = input('floor in european building: ')
    floor = int(floor)
    # convert to US standard
    us_floor = floor + 1
    print('Floor in US building: ' + str(us_floor))
