# %%
#Exercises: Day 8
#Create an empty dictionary called dog
dog = {}

#Add name, color, breed, legs, age to the dog dictionary
dog['name'] = 'Diogee'
dog['color'] = 'Brown'
dog['breed'] = 'Pitbull'
dog['legs'] = 4
dog['age'] = 5

#Create a student dictionary and add first_name, last_name, gender, age, marital_status, skills, country, city and address as keys for the dictionary.
student = {
    'first_name': 'Bob',
    'last_name': 'Ny',
    'gender': 'Male',
    'age': 22,
    'marital_status': 'Single',
    'skills': ['Python', 'Data Analysis', 'Machine Learning'],
    'country': 'SA',
    'city': 'Johannesburg',
    'address': '123 Main St'
}

#Get the length of the student dictionary
student_length = len(student)
print("Length of student dictionary:", student_length)
# Out:
# Length of student dictionary: 9

# %%
# Get the value of skills and check the data type, it should be a list
skills = student.get('skills')
print("Skills:", type(skills))

# Modify the skills values by adding one or two skills
student['skills'].extend(['Deep Learning', 'Data Visualization'])

# Get the dictionary keys as a list
keys_list = list(student.keys())
print("Dictionary keys:", keys_list)

# Get the dictionary values as a list
values_list = list(student.values())
print("Dictionary values:", values_list)

# Change the dictionary to a list of tuples using items() method
items_list = list(student.items())
print("Dictionary items as list of tuples:", items_list)

# Delete one of the items in the dictionary
del student['marital_status']
print("Student dictionary after deleting marital_status:", student)

# Delete one of the dictionaries
del dog
print("Dog dictionary deleted.")
# Out:
# Skills: <class 'list'>
# Dictionary keys: ['first_name', 'last_name', 'gender', 'age', 'marital_status', 'skills', 'country', 'city', 'address']
# Dictionary values: ['Bob', 'Ny', 'Male', 22, 'Single', ['Python', 'Data Analysis', 'Machine Learning', 'Deep Learning', 'Data Visualization'], 'SA', 'Johannesburg', '123 Main St']
# Dictionary items as list of tuples: [('first_name', 'Bob'), ('last_name', 'Ny'), ('gender', 'Male'), ('age', 22), ('marital_status', 'Single'), ('skills', ['Python', 'Data Analysis', 'Machine Learning', 'Deep Learning', 'Data Visualization']), ('country', 'SA'), ('city', 'Johannesburg'), ('address', '123 Main St')]
# Student dictionary after deleting marital_status: {'first_name': 'Bob', 'last_name': 'Ny', 'gender': 'Male', 'age': 22, 'skills': ['Python', 'Data Analysis', 'Machine Learning', 'Deep Learning', 'Data Visualization'], 'country': 'SA', 'city': 'Johannesburg', 'address': '123 Main St'}
# Dog dictionary deleted.

# %% [markdown]
# Done !!
